# %%
with open('praju.rtf','w') as f:
  f.write('\n50 60')

# %%
import matplotlib.pyplot as plt
ax = plt.subplot()
ax.plot([1, 2, 3], [3, 5, 7])
ax.set_title('Line Example')
ax.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0, 10, 1)
y = 2*x + 1
plt.plot(x, y, 'b')
plt.xlabel('x')
plt.title('Line Plot Example')
plt.show()
